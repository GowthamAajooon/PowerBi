# %%
#Exploratory Data Analysis 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno

# %%
data = pd.read_csv("E:\EDA\EDA\TSLA.csv")

# %%
data.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
# This data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2956 entries, 0 to 2955
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2956 non-null   object
#  1   Open       2956 non-null   float64
#  2   High       2956 non-null   float64
#  3   Low        2956 non-null   float64
#  4   Close      2956 non-null   float64
#  5   Adj Close  2956 non-null   float64
#  6   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 161.8+ KB

# %%
data = pd.DataFrame({
    'date_column': ['2010-06-29', '2010-07-01', '2010-07-05'],
    'numeric_column1': [1.2, 2.4, 3.5],
    'numeric_column2': [4.5, 5.6, 6.7]
})

# Identify non-numeric columns
non_numeric_columns = data.select_dtypes(include=['object', 'datetime']).columns
print("Non-numeric columns:", non_numeric_columns)

# Option A: Convert non-numeric columns (example for date columns)
if 'date_column' in non_numeric_columns:
    data['date_column'] = pd.to_datetime(data['date_column'])
    data['date_column'] = data['date_column'].map(pd.Timestamp.timestamp)

# Drop any remaining non-numeric columns
data_numeric = data.select_dtypes(include=[float, int])
                                                                                                                                                                                 
# Calculate the correlation
correlation_matrix = data_numeric.corr()
print(correlation_matrix)
# Out:
# Non-numeric columns: Index(['date_column'], dtype='object')
#                  date_column  numeric_column1  numeric_column2
# date_column         1.000000         0.976929         0.981981
# numeric_column1     0.976929         1.000000         0.999685
# numeric_column2     0.981981         0.999685         1.000000

# %%
# Visiualize the correlation 
plt.figure(figsize=(10,10)) 
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >
